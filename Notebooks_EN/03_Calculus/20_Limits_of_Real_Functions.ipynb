# %% [markdown]
# # **20. Limits of Real Functions**
#
# ---
#
# ## **1. Definition of Limit**
# The limit of a function \( f(x) \) as \( x \) approaches \( a \) is the value \( L \) that \( f(x) \) gets arbitrarily close to as \( x \) gets closer to \( a \):
# $$
# \lim_{x \to a} f(x) = L
# $$
# If \( f(x) \) does not approach a finite value, the limit does not exist.
#
# ---
#
# ## **2. One-Sided Limits**
# ### **a. Left-Hand Limit**
# The left-hand limit of \( f(x) \) as \( x \to a^- \) is:
# $$
# \lim_{x \to a^-} f(x) = L
# $$
#
# ### **b. Right-Hand Limit**
# The right-hand limit of \( f(x) \) as \( x \to a^+ \) is:
# $$
# \lim_{x \to a^+} f(x) = L
# $$
#
# ### **c. Limit Existence**
# A limit exists if and only if:
# $$
# \lim_{x \to a^-} f(x) = \lim_{x \to a^+} f(x)
# $$
#
# ---
#
# ## **3. Limits at Infinity**
# For \( x \to \infty \) or \( x \to -\infty \), the behavior of \( f(x) \) determines the limit:
# $$
# \lim_{x \to \infty} f(x) = L \quad \text{or} \quad \lim_{x \to -\infty} f(x) = L
# $$
#
# ---
#
# ## **4. Special Techniques for Limits**
# ### **a. Direct Substitution**
# If \( f(a) \) exists and is finite, then:
# $$
# \lim_{x \to a} f(x) = f(a)
# $$
#
# ### **b. Factoring**
# Used when direct substitution leads to an indeterminate form like \( \frac{0}{0} \).
#
# ### **c. Rationalization**
# Used to simplify expressions, especially with square roots.
#
# ### **d. L'Hôpital's Rule**
# If:
# $$
# \lim_{x \to a} \frac{f(x)}{g(x)} = \frac{0}{0} \quad \text{or} \quad \frac{\infty}{\infty},
# $$
# then:
# $$
# \lim_{x \to a} \frac{f(x)}{g(x)} = \lim_{x \to a} \frac{f'(x)}{g'(x)}.
# $$
#
# ---
#
# ## **5. Practice Problems**
# ### **a. Find:**
# 1. $$ \lim_{x \to 2} \frac{x^2 - 4}{x - 2} $$
# 2. $$ \lim_{x \to \infty} \frac{3x^2 + 2x}{2x^2 + 5} $$
#
# ### **b. Prove Using L'Hôpital's Rule:**
# 1. $$ \lim_{x \to 0} \frac{\sin(x)}{x} $$
#
# ---
#
# ## **Python Solutions**
# ### **1. lim (x^2 - 4) / (x - 2) as x -> 2**
# $$
# \lim_{x \to 2} \frac{x^2 - 4}{x - 2}
# $$
# This can be solved by factoring:
# $$
# \frac{x^2 - 4}{x - 2} = \frac{(x - 2)(x + 2)}{x - 2} = x + 2
# $$
# So:
# $$
# \lim_{x \to 2} \frac{x^2 - 4}{x - 2} = 4
# $$
#
# ---
#
# ### **2. lim (3x^2 + 2x) / (2x^2 + 5) as x -> infinity**
# $$
# \lim_{x \to \infty} \frac{3x^2 + 2x}{2x^2 + 5}
# $$
# Take the leading terms:
# $$
# \frac{3x^2}{2x^2} = \frac{3}{2}
# $$
# So:
# $$
# \lim_{x \to \infty} \frac{3x^2 + 2x}{2x^2 + 5} = \frac{3}{2}
# $$
#
# ---
#
# ### **3. Prove Using L'Hôpital's Rule**
# $$
# \lim_{x \to 0} \frac{\sin(x)}{x}
# $$
# Apply L'Hôpital's Rule:
# $$
# \frac{\sin(x)}{x} = \frac{\cos(x)}{1}
# $$
# So:
# $$
# \lim_{x \to 0} \frac{\sin(x)}{x} = 1
# $$
#
# ---
# """

# %% [markdown]
# # 20_Limits_of_Real_Functions questions solutions

# %%
from sympy import symbols, limit, sin, oo

# Define the variable
x = symbols('x')

# 1. Compute lim (x^3 + 2x^2) / (x^4 - 3x^3) as x -> infinity
expr1 = (x**3 + 2*x**2) / (x**4 - 3*x**3)
limit1 = limit(expr1, x, oo)
print(f"1. lim (x^3 + 2x^2) / (x^4 - 3x^3) as x -> infinity = {limit1}")

# 2. Compute lim sin(3x) / (2x + 1) as x -> 0
expr2 = sin(3*x) / (2*x + 1)
limit2 = limit(expr2, x, 0)
print(f"2. lim sin(3x) / (2x + 1) as x -> 0 = {limit2}")

# 3a. Find horizontal asymptotes of f(x) = (x^2 - 1) / (x^2 + 1)
f = (x**2 - 1) / (x**2 + 1)
horizontal_asymptote_f = limit(f, x, oo)
print(f"3a. Horizontal asymptote of f(x) = (x^2 - 1) / (x^2 + 1) as x -> infinity = {horizontal_asymptote_f}")

# 3b. Find horizontal asymptotes of g(x) = sin(x) / (x^2 + 1)
g = sin(x) / (x**2 + 1)
horizontal_asymptote_g = limit(g, x, oo)
print(f"3b. Horizontal asymptote of g(x) = sin(x) / (x^2 + 1) as x -> infinity = {horizontal_asymptote_g}")
# Out:
# 1. lim (x^3 + 2x^2) / (x^4 - 3x^3) as x -> infinity = 0
# 2. lim sin(3x) / (2x + 1) as x -> 0 = 0
# 3a. Horizontal asymptote of f(x) = (x^2 - 1) / (x^2 + 1) as x -> infinity = 1
# 3b. Horizontal asymptote of g(x) = sin(x) / (x^2 + 1) as x -> infinity = 0
